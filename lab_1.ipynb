# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
d = pd.read_csv("trades_btc_usdt.csv")

# %%
import datetime
datetime.datetime.fromtimestamp(d.eventTime/1000.0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-4ebbf679cb9b> in <module>()
#       1 import datetime
# ----> 2 datetime.datetime.fromtimestamp(d.eventTime/1000.0)
#
# ~/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/pandas/core/series.py in wrapper(self)
#     115             return converter(self.iloc[0])
#     116         raise TypeError("cannot convert the series to "
# --> 117                         "{0}".format(str(converter)))
#     118
#     119     return wrapper
#
# TypeError: cannot convert the series to <class 'int'>

# %%
d.head()
# Out:
#        eventTime   price  quantity  isBuyerMaker   symbol
# 0  1530917978628  6574.7  0.150870             1  BTCUSDT
# 1  1530917978674  6574.7  0.038068             1  BTCUSDT
# 2  1530917979621  6574.7  0.281313             1  BTCUSDT
# 3  1530917980770  6574.7  0.038044             1  BTCUSDT
# 4  1530917980896  6574.7  0.011630             1  BTCUSDT

# %%
a = d.quantity
a = a.loc[:1000]
a = a[a<0.1]

# %%
a.shape
# Out:
# (1001,)

# %%
plt.figure(figsize=(20,10))
a.plot()
